# %% [markdown]
# # Person Identification by Gait on the Gotcha Dataset
# Submitted by Marvin Brenner

# %% [markdown]
# ## Overview of Tasks:
# 1) Extract frames from video, we don’t need all the frames but samples of consecutive
# frames<br>
# 2) Use Real time Multi-Person 2D Pose Estimation Using Part Affinity Fields to detect the
# skeleton of the subject in the frame, particularly his feature body points<br>
# 3) Store the position/coordinates of consecutive frame feature points in an array to create
# the pattern array (the pattern array store informations about the subject movement
# variations in time)<br>
# 4) Create a NN that use as input the pattern array and give us the user id as output:<br>
# 5) Use a lot of pattern array samples to train the network<br>
# 6) Try to reach the highest accuracy chosing the best loss function.<br>
# 7) Additionally classify if each video is inside, outside or with a flashlight

# %% [markdown]
# ## Dataset Content Description:
# Content of the Dataset, Folders:<br>
# Inside each folder there are two numbers: first number is the number of the folder and the second number is the subject's ID. <br>
# 1_Indoor lights - cooperative  = there are videos of 62 subjects indoor and in cooperative way.<br>
# 2_Indoor light - non cooperative = there are videos of 62 subjects indoor and in cooperative way. <br>
# 3_Indoor flash - cooperative  = there are videos of 62 subjects indoor with light on and flash on, in cooperative way.<br>
# 4_Indoor flash - non cooperative = there are videos of 62 subjects indoor with light on and flash on, in non cooperative way. <br>
# 5_Outdoor - cooperative  = there are videos of 62 subjects outdoor in cooperative way. <br>
# 6_Outdoor - non cooperative = there are videos of 62 subjects outdoor in non cooperative way. <br>
# 7_180 head video =  there are videos of the face in 180¡ (from ear to ear) of 62 subjects.<br>
# 8_Stairs - cooperative = there are videos of 6 subjects climbing the stairs in 3 different angles with 3 different devices (A-B-C), in cooperative way.<br>
# 9_Stairs - non cooperative =  there are videos of 6 subjects climbing the stairs in 3 different angles with 3 different devices (A-B-C), in non cooperative way.<br>
# 10_Outdoor path - cooperative = there are videos of 12 subjects walking outdoor along a path in cooperative way. (iPhone)<br>
# 11_Outdoor path - non cooperative = there are videos of 12 subjects walking outdoor along a path in non cooperative way. <br>(iPhone)
# 12_Derived file attached = there are two tipes of folders (1) HPE_x where x = 1, 2, 3, ... 62.  (2) Landmarks<br>
#
# (1) HPE_x folder contains the 3D model of the subject x and 2223 images with the head rotated in pitch, yaw and roll<br>
# (2) Landmarks folder contains Body landmarks and face landmarks of 62 subjects in the videos 1, 2, 3, 4, 5, 6.<br>

# %%
# %matplotlib inline
import pandas as pd                                   # for working with large dataframes
import numpy as np                                    # for working with efficient numpy arrays
import os                                             # for operating system
import shutil                                         # for more utilities
import csv                                            # for reading excel tables and similar files
import matplotlib.pyplot as plt                       # for plotting the images
import cv2                                            # for capturing videos
import math                                           # for mathematical operations
from keras.preprocessing import image                 # for preprocessing the images
from keras.utils import np_utils                      # some utilities
from skimage.transform import resize                  # for resizing images
from scipy import ndimage                             # for rotating images
from config_reader import config_reader               # for 2D pose estimation
from model.cmu_model import get_testing_model         # for loading the affinity model
import time                                           # capturing the time needed for some operations
from tqdm import tqdm_notebook as tqdm                # having progress bars for loops
from sklearn.model_selection import train_test_split  # splitting training and test data
from sklearn.preprocessing import OneHotEncoder       # Encoding labels to vectors
from keras.utils import to_categorical                # Encoding Labels to numbers
from keras.models import Sequential                   # Building network architecture
from keras.layers import Dense, BatchNormalization, LSTM, Conv2D, Conv3D, Flatten    # Neural Network Layers
from sklearn.utils import resample
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

#pandas display settings
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 100)

wpath = os.getcwd()
print ("The current working directory is %s" % wpath)
# Out:
# Using TensorFlow backend.
# The current working directory is C:\Users\marvi\Downloads\CASA_Handin_Marvin_Brenner-master\CASA_Handin_Marvin_Brenner-master

# %% [markdown]
# # Steps of first Notebook
# 1) Extracting the Frames from the Videos <br>
# 2) Performing 2D Pose Estimation and storing the Joint Positions<br>

# %% [markdown]
# # 3) Loading the extracted Joint Data and storing the positions over time

# %% [markdown]
# Now I'm loading all the joint XY coordinates from the textfiles and put them into a structured array.<br>
# All samples consists of the ID of a subject, the File name including the Frame number and XY coordinates of the 18 joints.

# %%
path = './joint_data/'

dataframe = []
coords = []
framecoords= []

n=1
for filename in tqdm(sorted(os.listdir(path))):
    
    if('frame' in filename):
        
        framecoords= []
        name = filename[0:-4]
        
        #read the joint file
        label = filename[2:5]
        f = open(path+filename, 'r')
        lines = f.readlines()
        count = len(lines)
        folder = filename[0]
               
        #get the XY-coordinates of every joint
        for line in lines[1:]:
            for string in line.splitlines():
                a = string.split(" ")
                a = a[0:-2]
                
                if(len(a)>2):
                    a[:]=a[0:2]
                    a = [float(x) for x in a]
                    
                elif(len(a)==0):
                    a=[np.nan, np.nan] 
                    
                elif("NaN" in a):
                    a=[np.nan, np.nan] 
                
                else:
                    a = [float(x) for x in a]
                    a = np.array(a)
                framecoords.append(a)
                
              
        
            
        dataframe.append([label,
                          name[0:5],
                          name[11:],
                          folder,
                          framecoords[0][0],
                          framecoords[0][1],
                          framecoords[1][0],
                          framecoords[1][1],
                          framecoords[2][0],
                          framecoords[2][1],
                          framecoords[3][0],
                          framecoords[3][1],
                          framecoords[4][0],
                          framecoords[4][1],
                          framecoords[5][0],
                          framecoords[5][1],
                          framecoords[6][0],
                          framecoords[6][1],
                          framecoords[7][0],
                          framecoords[7][1],
                          framecoords[8][0],
                          framecoords[8][1],
                          framecoords[9][0],
                          framecoords[9][1],
                          framecoords[10][0],
                          framecoords[10][1],
                          framecoords[11][0],
                          framecoords[11][1],
                          framecoords[12][0],
                          framecoords[12][1],
                          framecoords[13][0],
                          framecoords[13][1],
                          framecoords[14][0],
                          framecoords[14][1],
                          framecoords[15][0],
                          framecoords[15][1],
                          framecoords[16][0],
                          framecoords[16][1],
                          framecoords[17][0],
                          framecoords[17][1],                 
                          ])
   
        file_contents = f.read()
        f.close()
    n=n+1
# Out:
# HBox(children=(IntProgress(value=0, max=72624), HTML(value='')))

# %% [markdown]
# I looked up the correct order of Joints in the 2D Pose Estimation Paper to ensure all columns are named correctly

# %%
df = pd.DataFrame(dataframe, columns = ['ID','VideoNr','FrameNr', 'Folder' ,'noseX','noseY', 'neckX','neckY', 'right_shoulderX',
                                        'right_shoulderY','right_elbowX','right_elbowY','right_wristX', 'right_wristY',
                                        'left_shoulderX','left_shoulderY', 'left_elbowX', 'left_elbowY', 'left_wristX',
                                        'left_wristY', 'right_hipX', 'right_hipY', 'right_kneeX', 'right_kneeY', 
                                         'right_ankleX', 'right_ankleY', 'left_hipX','left_hipY', 'left_kneeX', 'left_kneeY',
                                         'left_ankleX',  'left_ankleY', 'left_eyeX', 'left_eyeY','right_eyeX', 'right_eyeY',
                                      'left_earX' ,'left_earY','right_earX','right_earY'])
df
# Out:
#         ID VideoNr FrameNr Folder  noseX  noseY  neckX  neckY  \
# 0      001   1_001      00      1   32.0   53.0   25.0   72.0
# 1      001   1_001      01      1   31.0   52.0   25.0   72.0
# 2      001   1_001     010      1   28.0   52.0   22.0   72.0
# 3      001   1_001    0100      1   31.0   63.0   33.0   89.0
# 4      001   1_001    0101      1   31.0   64.0   33.0   89.0
# ...    ...     ...     ...    ...    ...    ...    ...    ...
# 72617  062   6_062     095      6   49.0   74.0   46.0   92.0
# 72618  062   6_062     096      6   50.0   74.0   46.0   92.0
# 72619  062   6_062     097      6   50.0   74.0   45.0   92.0
# 72620  062   6_062     098      6   50.0   73.0   45.0   91.0
# 72621  062   6_062     099      6   49.0   73.0   45.0   92.0
#
#        right_shoulderX  right_shoulderY  right_elbowX  right_elbowY  \
# 0                  0.0             72.0           NaN           NaN
# 1                  0.0             72.0           NaN           NaN
# 2                  0.0             72.0           NaN           NaN
# 3                  0.0             91.0           NaN           NaN
# 4                  0.0             91.0           NaN           NaN
# ...                ...              ...           ...           ...
# 72617             32.0             95.0          26.0         121.0
# 72618             31.0             95.0          25.0         122.0
# 72619             31.0             95.0          25.0         121.0
# 72620             31.0             94.0          25.0         121.0
# 72621             31.0             95.0          24.0         121.0
#
#        right_wristX  right_wristY  left_shoulderX  left_shoulderY  \
# 0               NaN           NaN            47.0            73.0
# 1               NaN           NaN            46.0            73.0
# 2               NaN           NaN            44.0            71.0
# 3               NaN           NaN            64.0            87.0
# 4               NaN           NaN            64.0            87.0
# ...             ...           ...             ...             ...
# 72617          37.0         141.0            59.0            89.0
# 72618          36.0         140.0            59.0            89.0
# 72619          36.0         140.0            59.0            89.0
# 72620          35.0         140.0            59.0            89.0
# 72621          34.0         141.0            59.0            89.0
#
#        left_elbowX  left_elbowY  left_wristX  left_wristY  right_hipX  \
# 0             52.0        101.0         54.0        127.0         8.0
# 1             52.0        100.0         54.0        127.0         8.0
# 2             51.0         99.0         53.0        125.0         5.0
# 3             77.0        125.0         82.0        167.0        15.0
# 4             77.0        126.0         81.0        168.0        14.0
# ...            ...          ...          ...          ...         ...
# 72617         67.0        111.0         71.0        128.0        49.0
# 72618         67.0        110.0         71.0        128.0        48.0
# 72619         66.0        111.0         70.0        128.0        48.0
# 72620         66.0        110.0         70.0        127.0        47.0
# 72621         66.0        111.0         70.0        128.0        47.0
#
#        right_hipY  right_kneeX  right_kneeY  right_ankleX  right_ankleY  \
# 0           136.0         10.0        179.0           NaN           NaN
# 1           136.0          9.0        181.0           NaN           NaN
# 2           137.0          6.0        180.0           NaN           NaN
# 3           183.0          NaN          NaN           NaN           NaN
# 4           183.0          NaN          NaN           NaN           NaN
# ...           ...          ...          ...           ...           ...
# 72617       142.0         54.0        177.0          57.0         191.0
# 72618       141.0         53.0        176.0          56.0         191.0
# 72619       141.0         52.0        175.0          56.0         191.0
# 72620       142.0         51.0        175.0           NaN           NaN
# 72621       141.0         51.0        174.0           NaN           NaN
#
#        left_hipX  left_hipY  left_kneeX  left_kneeY  left_ankleX  left_ankleY  \
# 0           35.0      137.0        28.0       181.0          NaN          NaN
# 1           34.0      137.0        27.0       181.0          NaN          NaN
# 2           32.0      137.0        23.0       179.0          NaN          NaN
# 3           52.0      183.0         NaN         NaN          NaN          NaN
# 4           51.0      183.0         NaN         NaN          NaN          NaN
# ...          ...        ...         ...         ...          ...          ...
# 72617       66.0      137.0        77.0       171.0         67.0        191.0
# 72618       66.0      137.0        76.0       170.0         68.0        191.0
# 72619       66.0      137.0        75.0       170.0          NaN          NaN
# 72620       65.0      137.0        75.0       170.0          NaN          NaN
# 72621       65.0      137.0        74.0       172.0          NaN          NaN
#
#        left_eyeX  left_eyeY  right_eyeX  right_eyeY  left_earX  left_earY  \
# 0           27.0       48.0        35.0        48.0       18.0       48.0
# 1           26.0       47.0        35.0        48.0       17.0       47.0
# 2           23.0       47.0        31.0        47.0       13.0       47.0
# 3           25.0       55.0        38.0        54.0       15.0       56.0
# 4           23.0       55.0        37.0        55.0       14.0       56.0
# ...          ...        ...         ...         ...        ...        ...
# 72617       46.0       72.0        51.0        71.0       38.0       73.0
# 72618       46.0       71.0        51.0        71.0       37.0       73.0
# 72619       46.0       71.0        51.0        71.0       37.0       73.0
# 72620       46.0       71.0        51.0        70.0       37.0       73.0
# 72621       46.0       71.0        51.0        70.0       37.0       73.0
#
#        right_earX  right_earY
# 0            40.0        49.0
# 1            39.0        49.0
# 2            36.0        47.0
# 3            47.0        55.0
# 4            46.0        56.0
# ...           ...         ...
# 72617         NaN         NaN
# 72618         NaN         NaN
# 72619         NaN         NaN
# 72620         NaN         NaN
# 72621         NaN         NaN
#
# [72622 rows x 40 columns]

# %% [markdown]
# I looked up the correct order of Joints in the 2D Pose Estimation Paper to ensure all columns are named correctly
# Joints like the ones of the nose and ears are less important for gait analysis, so before continuing I wanted to see which columns miss the most values. As you can see in the table below, unfortunately the ankles haven't been recognized correctly a lot of times, although they are important for gait analysis.

# %%
percent_missing = df[df.columns[4:]].isnull().sum() * 100 / len(df) #to count nans
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})

missing_value_df.sort_values('percent_missing', inplace=True)
missing_value_df
# Out:
#                 percent_missing
# neckX                  0.176255
# neckY                  0.176255
# noseX                  0.410344
# noseY                  0.410344
# left_shoulderX         0.692628
# ...                         ...
# right_kneeX           55.524497
# right_ankleY          79.546143
# right_ankleX          79.546143
# left_ankleX           81.109030
# left_ankleY           81.109030
#
# [36 rows x 1 columns]

# %% [markdown]
# Here I'm linear interpolating the missing values which provides slightly better accuracy than just using a mean value for each missing one. Dropping all nans is not an option because there would't be enough training data.

# %%
df[df.columns[4:]] = df[df.columns[4:]].astype(float)
df[df.columns[4:]] = df[df.columns[4:]].interpolate(method='linear', axis=0).ffill().bfill()
df
# Out:
#         ID VideoNr FrameNr Folder  noseX  noseY  neckX  neckY  \
# 0      001   1_001      00      1   32.0   53.0   25.0   72.0
# 1      001   1_001      01      1   31.0   52.0   25.0   72.0
# 2      001   1_001     010      1   28.0   52.0   22.0   72.0
# 3      001   1_001    0100      1   31.0   63.0   33.0   89.0
# 4      001   1_001    0101      1   31.0   64.0   33.0   89.0
# ...    ...     ...     ...    ...    ...    ...    ...    ...
# 72617  062   6_062     095      6   49.0   74.0   46.0   92.0
# 72618  062   6_062     096      6   50.0   74.0   46.0   92.0
# 72619  062   6_062     097      6   50.0   74.0   45.0   92.0
# 72620  062   6_062     098      6   50.0   73.0   45.0   91.0
# 72621  062   6_062     099      6   49.0   73.0   45.0   92.0
#
#        right_shoulderX  right_shoulderY  right_elbowX  right_elbowY  \
# 0                  0.0             72.0          12.0         134.0
# 1                  0.0             72.0          12.0         134.0
# 2                  0.0             72.0          12.0         134.0
# 3                  0.0             91.0          12.0         134.0
# 4                  0.0             91.0          12.0         134.0
# ...                ...              ...           ...           ...
# 72617             32.0             95.0          26.0         121.0
# 72618             31.0             95.0          25.0         122.0
# 72619             31.0             95.0          25.0         121.0
# 72620             31.0             94.0          25.0         121.0
# 72621             31.0             95.0          24.0         121.0
#
#        right_wristX  right_wristY  left_shoulderX  left_shoulderY  \
# 0               8.0         170.0            47.0            73.0
# 1               8.0         170.0            46.0            73.0
# 2               8.0         170.0            44.0            71.0
# 3               8.0         170.0            64.0            87.0
# 4               8.0         170.0            64.0            87.0
# ...             ...           ...             ...             ...
# 72617          37.0         141.0            59.0            89.0
# 72618          36.0         140.0            59.0            89.0
# 72619          36.0         140.0            59.0            89.0
# 72620          35.0         140.0            59.0            89.0
# 72621          34.0         141.0            59.0            89.0
#
#        left_elbowX  left_elbowY  left_wristX  left_wristY  right_hipX  \
# 0             52.0        101.0         54.0        127.0         8.0
# 1             52.0        100.0         54.0        127.0         8.0
# 2             51.0         99.0         53.0        125.0         5.0
# 3             77.0        125.0         82.0        167.0        15.0
# 4             77.0        126.0         81.0        168.0        14.0
# ...            ...          ...          ...          ...         ...
# 72617         67.0        111.0         71.0        128.0        49.0
# 72618         67.0        110.0         71.0        128.0        48.0
# 72619         66.0        111.0         70.0        128.0        48.0
# 72620         66.0        110.0         70.0        127.0        47.0
# 72621         66.0        111.0         70.0        128.0        47.0
#
#        right_hipY  right_kneeX  right_kneeY  right_ankleX  right_ankleY  \
# 0           136.0    10.000000   179.000000          30.0         191.0
# 1           136.0     9.000000   181.000000          30.0         191.0
# 2           137.0     6.000000   180.000000          30.0         191.0
# 3           183.0     6.272727   180.090909          30.0         191.0
# 4           183.0     6.545455   180.181818          30.0         191.0
# ...           ...          ...          ...           ...           ...
# 72617       142.0    54.000000   177.000000          57.0         191.0
# 72618       141.0    53.000000   176.000000          56.0         191.0
# 72619       141.0    52.000000   175.000000          56.0         191.0
# 72620       142.0    51.000000   175.000000          56.0         191.0
# 72621       141.0    51.000000   174.000000          56.0         191.0
#
#        left_hipX  left_hipY  left_kneeX  left_kneeY  left_ankleX  left_ankleY  \
# 0           35.0      137.0   28.000000  181.000000         69.0        191.0
# 1           34.0      137.0   27.000000  181.000000         69.0        191.0
# 2           32.0      137.0   23.000000  179.000000         69.0        191.0
# 3           52.0      183.0   22.909091  179.181818         69.0        191.0
# 4           51.0      183.0   22.818182  179.363636         69.0        191.0
# ...          ...        ...         ...         ...          ...          ...
# 72617       66.0      137.0   77.000000  171.000000         67.0        191.0
# 72618       66.0      137.0   76.000000  170.000000         68.0        191.0
# 72619       66.0      137.0   75.000000  170.000000         68.0        191.0
# 72620       65.0      137.0   75.000000  170.000000         68.0        191.0
# 72621       65.0      137.0   74.000000  172.000000         68.0        191.0
#
#        left_eyeX  left_eyeY  right_eyeX  right_eyeY  left_earX  left_earY  \
# 0           27.0       48.0        35.0        48.0       18.0       48.0
# 1           26.0       47.0        35.0        48.0       17.0       47.0
# 2           23.0       47.0        31.0        47.0       13.0       47.0
# 3           25.0       55.0        38.0        54.0       15.0       56.0
# 4           23.0       55.0        37.0        55.0       14.0       56.0
# ...          ...        ...         ...         ...        ...        ...
# 72617       46.0       72.0        51.0        71.0       38.0       73.0
# 72618       46.0       71.0        51.0        71.0       37.0       73.0
# 72619       46.0       71.0        51.0        71.0       37.0       73.0
# 72620       46.0       71.0        51.0        70.0       37.0       73.0
# 72621       46.0       71.0        51.0        70.0       37.0       73.0
#
#        right_earX  right_earY
# 0            40.0        49.0
# 1            39.0        49.0
# 2            36.0        47.0
# 3            47.0        55.0
# 4            46.0        56.0
# ...           ...         ...
# 72617        60.0        76.0
# 72618        60.0        76.0
# 72619        60.0        76.0
# 72620        60.0        76.0
# 72621        60.0        76.0
#
# [72622 rows x 40 columns]

# %% [markdown]
# In order to have more balanced training data, I dropped the columns of the ankles and ears.

# %%
df2=df.drop(['left_ankleX','right_ankleX','left_earX', 'right_earX','left_eyeX','left_eyeY',
             'right_eyeX', 'right_eyeY','left_ankleY','right_ankleY','left_earY', 'right_earY'], axis=1)

# %% [markdown]
# Here I'm just fixing the naming of the frames

# %%
index = 0

#remove the dots of the frame names
for name in tqdm(df2.loc[:,("FrameNr")]):
    
    
    if(len(name)==2):
        name = "00"+name[-2:]
        df2.at[index,"FrameNr"] = name
        index+=1
        
    elif(len(name)==3):
        name = "0"+name[-3:]
        df2.at[index,"FrameNr"] = name
        index+=1
        
    else:
        index+=1
        
df2 = df2.sort_values(by =['VideoNr','FrameNr'], ascending=[True, True] )
df2
# Out:
# HBox(children=(IntProgress(value=0, max=72622), HTML(value='')))
#         ID VideoNr FrameNr Folder  noseX  noseY  neckX  neckY  \
# 0      001   1_001    0000      1   32.0   53.0   25.0   72.0
# 1      001   1_001    0001      1   31.0   52.0   25.0   72.0
# 112    001   1_001    0002      1   31.0   52.0   25.0   72.0
# 154    001   1_001    0003      1   30.0   52.0   24.0   72.0
# 165    001   1_001    0004      1   30.0   52.0   24.0   71.0
# ...    ...     ...     ...    ...    ...    ...    ...    ...
# 72529  062   6_062    0196      6   52.0   80.0   48.0  103.0
# 72530  062   6_062    0197      6   52.0   80.0   49.0  103.0
# 72531  062   6_062    0198      6   52.0   80.0   48.0  104.0
# 72532  062   6_062    0199      6   52.0   80.0   48.0  104.0
# 72535  062   6_062    0200      6   52.0   80.0   48.0  105.0
#
#        right_shoulderX  right_shoulderY  right_elbowX  right_elbowY  \
# 0                  0.0             72.0          12.0         134.0
# 1                  0.0             72.0          12.0         134.0
# 112                2.0             71.0          12.0         134.0
# 154                0.0             72.0          12.0         134.0
# 165                0.0             71.0          12.0         134.0
# ...                ...              ...           ...           ...
# 72529             26.0            104.0          18.0         141.0
# 72530             26.0            105.0          18.0         141.0
# 72531             25.0            105.0          18.0         141.0
# 72532             24.0            106.0          18.0         143.0
# 72535             25.0            106.0          18.0         143.0
#
#        right_wristX  right_wristY  left_shoulderX  left_shoulderY  \
# 0               8.0         170.0            47.0            73.0
# 1               8.0         170.0            46.0            73.0
# 112             8.0         170.0            46.0            72.0
# 154             8.0         170.0            46.0            72.0
# 165             8.0         170.0            45.0            72.0
# ...             ...           ...             ...             ...
# 72529          24.0         171.0            71.0           102.0
# 72530          25.0         172.0            71.0           102.0
# 72531          24.0         173.0            71.0           103.0
# 72532          25.0         175.0            71.0           103.0
# 72535          24.0         174.0            71.0           103.0
#
#        left_elbowX  left_elbowY  left_wristX  left_wristY  right_hipX  \
# 0             52.0        101.0         54.0        127.0         8.0
# 1             52.0        100.0         54.0        127.0         8.0
# 112           52.0        100.0         54.0        126.0         8.0
# 154           52.0        100.0         54.0        126.0         8.0
# 165           52.0        100.0         54.0        126.0         7.0
# ...            ...          ...          ...          ...         ...
# 72529         82.0        139.0         81.0        170.0        38.0
# 72530         82.0        138.0         81.0        170.0        39.0
# 72531         83.0        140.0         82.0        171.0        38.0
# 72532         84.0        140.0         83.0        172.0        38.0
# 72535         85.0        141.0         83.0        173.0        37.0
#
#        right_hipY  right_kneeX  right_kneeY  left_hipX  left_hipY  left_kneeX  \
# 0           136.0    10.000000        179.0       35.0      137.0   28.000000
# 1           136.0     9.000000        181.0       34.0      137.0   27.000000
# 112         136.0    10.000000        181.0       34.0      137.0   27.000000
# 154         136.0    11.000000        180.0       34.0      136.0   26.000000
# 165         137.0    12.000000        180.0       33.0      138.0   26.000000
# ...           ...          ...          ...        ...        ...         ...
# 72529       174.0    72.545455        167.0       65.0      172.0   76.545455
# 72530       176.0    72.909091        167.0       67.0      175.0   74.909091
# 72531       177.0    73.272727        167.0       67.0      175.0   73.272727
# 72532       177.0    73.636364        167.0       67.0      175.0   71.636364
# 72535       178.0    68.500000        164.5       67.0      177.0   88.000000
#
#        left_kneeY
# 0      181.000000
# 1      181.000000
# 112    181.000000
# 154    182.000000
# 165    181.000000
# ...           ...
# 72529  162.545455
# 72530  162.909091
# 72531  163.272727
# 72532  163.636364
# 72535  159.000000
#
# [72622 rows x 28 columns]

# %% [markdown]
# # Preprocessing
#
# In order for the neural network to learn the spatiotemporal relationship between the frames, I need to group them in a sequence, so I can feed it in a LSTM later.

# %% [markdown]
# Additional Parameters for recognizing gait: <br>
#
# Not possible due to missing joints:<br>
# • Step length: it is the short step length, obtained by the linear distance between two
# successive placements of the same foot<br>
# • Stride length: or long length obtained by the linear distance between the placements of
# both feet<br>
# • Step width: it is the linear distance between two equivalent points of both feet<br>
# • Step angle: it is the direction of the foot during the step<br>
# • Cadence: or rhythm, is the number of steps per time unit -> barely any differences in the videos used, because the distance walked is almost always the same<br>
#
#
#
# Possible:<br>
# • Gait phases: as the phases of the steps<br>
# • Body posture: in terms of bending, symmetry etc<br>

# %%
df3 = df2.copy()

# %% [markdown]
# Here I define some additional features to identify a persons gait. These are the vertical differences between both shoulders, hips and elbows.

# %%
#symmetry of body posture
df3["shoulder_sym"] = df3["right_shoulderY"]-df3["left_shoulderY"]  #shoulder height difference in Y
df3["hip_sym"] = df3["right_hipY"]-df3["left_hipY"]                 #hip height difference in Y
df3["elbow_sym"] = df3["right_elbowY"]-df3["left_elbowY"]           #elbow height difference in Y
df3["knee_sym"] = df3["right_kneeY"]-df3["left_kneeY"]           #elbow height difference in Y
df3
# Out:
#         ID VideoNr FrameNr Folder  noseX  noseY  neckX  neckY  \
# 0      001   1_001    0000      1   32.0   53.0   25.0   72.0
# 1      001   1_001    0001      1   31.0   52.0   25.0   72.0
# 112    001   1_001    0002      1   31.0   52.0   25.0   72.0
# 154    001   1_001    0003      1   30.0   52.0   24.0   72.0
# 165    001   1_001    0004      1   30.0   52.0   24.0   71.0
# ...    ...     ...     ...    ...    ...    ...    ...    ...
# 72529  062   6_062    0196      6   52.0   80.0   48.0  103.0
# 72530  062   6_062    0197      6   52.0   80.0   49.0  103.0
# 72531  062   6_062    0198      6   52.0   80.0   48.0  104.0
# 72532  062   6_062    0199      6   52.0   80.0   48.0  104.0
# 72535  062   6_062    0200      6   52.0   80.0   48.0  105.0
#
#        right_shoulderX  right_shoulderY  right_elbowX  right_elbowY  \
# 0                  0.0             72.0          12.0         134.0
# 1                  0.0             72.0          12.0         134.0
# 112                2.0             71.0          12.0         134.0
# 154                0.0             72.0          12.0         134.0
# 165                0.0             71.0          12.0         134.0
# ...                ...              ...           ...           ...
# 72529             26.0            104.0          18.0         141.0
# 72530             26.0            105.0          18.0         141.0
# 72531             25.0            105.0          18.0         141.0
# 72532             24.0            106.0          18.0         143.0
# 72535             25.0            106.0          18.0         143.0
#
#        right_wristX  right_wristY  left_shoulderX  left_shoulderY  \
# 0               8.0         170.0            47.0            73.0
# 1               8.0         170.0            46.0            73.0
# 112             8.0         170.0            46.0            72.0
# 154             8.0         170.0            46.0            72.0
# 165             8.0         170.0            45.0            72.0
# ...             ...           ...             ...             ...
# 72529          24.0         171.0            71.0           102.0
# 72530          25.0         172.0            71.0           102.0
# 72531          24.0         173.0            71.0           103.0
# 72532          25.0         175.0            71.0           103.0
# 72535          24.0         174.0            71.0           103.0
#
#        left_elbowX  left_elbowY  left_wristX  left_wristY  right_hipX  \
# 0             52.0        101.0         54.0        127.0         8.0
# 1             52.0        100.0         54.0        127.0         8.0
# 112           52.0        100.0         54.0        126.0         8.0
# 154           52.0        100.0         54.0        126.0         8.0
# 165           52.0        100.0         54.0        126.0         7.0
# ...            ...          ...          ...          ...         ...
# 72529         82.0        139.0         81.0        170.0        38.0
# 72530         82.0        138.0         81.0        170.0        39.0
# 72531         83.0        140.0         82.0        171.0        38.0
# 72532         84.0        140.0         83.0        172.0        38.0
# 72535         85.0        141.0         83.0        173.0        37.0
#
#        right_hipY  right_kneeX  right_kneeY  left_hipX  left_hipY  left_kneeX  \
# 0           136.0    10.000000        179.0       35.0      137.0   28.000000
# 1           136.0     9.000000        181.0       34.0      137.0   27.000000
# 112         136.0    10.000000        181.0       34.0      137.0   27.000000
# 154         136.0    11.000000        180.0       34.0      136.0   26.000000
# 165         137.0    12.000000        180.0       33.0      138.0   26.000000
# ...           ...          ...          ...        ...        ...         ...
# 72529       174.0    72.545455        167.0       65.0      172.0   76.545455
# 72530       176.0    72.909091        167.0       67.0      175.0   74.909091
# 72531       177.0    73.272727        167.0       67.0      175.0   73.272727
# 72532       177.0    73.636364        167.0       67.0      175.0   71.636364
# 72535       178.0    68.500000        164.5       67.0      177.0   88.000000
#
#        left_kneeY  shoulder_sym  hip_sym  elbow_sym  knee_sym
# 0      181.000000          -1.0     -1.0       33.0 -2.000000
# 1      181.000000          -1.0     -1.0       34.0  0.000000
# 112    181.000000          -1.0     -1.0       34.0  0.000000
# 154    182.000000           0.0      0.0       34.0 -2.000000
# 165    181.000000          -1.0     -1.0       34.0 -1.000000
# ...           ...           ...      ...        ...       ...
# 72529  162.545455           2.0      2.0        2.0  4.454545
# 72530  162.909091           3.0      1.0        3.0  4.090909
# 72531  163.272727           2.0      2.0        1.0  3.727273
# 72532  163.636364           3.0      2.0        3.0  3.363636
# 72535  159.000000           3.0      1.0        2.0  5.500000
#
# [72622 rows x 32 columns]

# %% [markdown]
# I scale all the inputs, to balance the input data. Otherwise the validation loss is oscillating strongly because some coordinates are way higher than others and get weighted more than they should.

# %%
df4 = df3.copy()
x = sc.fit_transform(df4[df4.columns[4:]])

# %%
df4[df4.columns[4:]]=x
df4
# Out:
#         ID VideoNr FrameNr Folder     noseX     noseY     neckX     neckY  \
# 0      001   1_001    0000      1 -1.126707 -2.316261 -1.697310 -2.356831
# 1      001   1_001    0001      1 -1.198774 -2.409463 -1.697310 -2.356831
# 112    001   1_001    0002      1 -1.198774 -2.409463 -1.697310 -2.356831
# 154    001   1_001    0003      1 -1.270841 -2.409463 -1.782347 -2.356831
# 165    001   1_001    0004      1 -1.270841 -2.409463 -1.782347 -2.434348
# ...    ...     ...     ...    ...       ...       ...       ...       ...
# 72529  062   6_062    0196      6  0.314641  0.200208  0.258535  0.046190
# 72530  062   6_062    0197      6  0.314641  0.200208  0.343572  0.046190
# 72531  062   6_062    0198      6  0.314641  0.200208  0.258535  0.123707
# 72532  062   6_062    0199      6  0.314641  0.200208  0.258535  0.123707
#        left_kneeY  shoulder_sym   hip_sym  elbow_sym  knee_sym
# 0        0.386875     -0.515895 -0.535141   2.048787 -0.600612
# 1        0.386875     -0.515895 -0.535141   2.121184 -0.249498
# 112      0.386875     -0.515895 -0.535141   2.121184 -0.249498
# 154      0.446828     -0.359784 -0.356310   2.121184 -0.600612
# 165      0.386875     -0.515895 -0.535141   2.121184 -0.425055
# ...           ...           ...       ...        ...       ...
# 72529   -0.719515     -0.047561  0.001353  -0.195521  0.532529
# 72530   -0.697714      0.108551 -0.177478  -0.123124  0.468690
# 72531   -0.675913     -0.047561  0.001353  -0.267919  0.404851
# 72532   -0.654113      0.108551  0.001353  -0.123124  0.341012
# 72535   -0.932073      0.108551 -0.177478  -0.195521  0.716065
#
# [72622 rows x 32 columns]

# %% [markdown]
# In order to improve efficiency and reduce redundant information, Principal Component Analysis was performed on all features. This works especially well with small datasets like this.

# %%
from sklearn import decomposition

scaled_data = df4[df4.columns[4:]]
pca = decomposition.PCA()
pca_data=pca.fit_transform(scaled_data)
df4[df4.columns[4:]] = pca_data
df4 = df4.sort_values(by =['VideoNr','FrameNr'], ascending=[True, True] )
df4
# Out:
#         ID VideoNr FrameNr Folder     noseX     noseY     neckX     neckY  \
# 0      001   1_001    0000      1  6.145160 -3.542375 -3.370829  0.231288
# 1      001   1_001    0001      1  6.221389 -3.608924 -3.442695  0.313658
# 112    001   1_001    0002      1  6.251827 -3.512333 -3.483198  0.286249
# 154    001   1_001    0003      1  6.275452 -3.603763 -3.505526  0.247025
# 165    001   1_001    0004      1  6.318626 -3.659531 -3.494006  0.204336
# ...    ...     ...     ...    ...       ...       ...       ...       ...
# 72529  062   6_062    0196      6 -1.940712  0.229640 -0.147440 -0.042801
# 72530  062   6_062    0197      6 -2.068142  0.305274 -0.248968  0.083150
# 72531  062   6_062    0198      6 -2.157619  0.134017 -0.152142 -0.026506
# 72532  062   6_062    0199      6 -2.255820  0.108565 -0.250662  0.132897
# 72535  062   6_062    0200      6 -2.408219  0.158160 -0.182150  0.052717
#
#        right_shoulderX  right_shoulderY  right_elbowX  right_elbowY  \
# 0            -1.159242        -1.147212     -1.827763     -0.137609
# 1            -1.198673        -0.895350     -1.803333     -0.272246
# 112          -1.197064        -0.891255     -1.779557     -0.329345
# 154          -1.008068        -1.014995     -1.871506     -0.041930
# 165          -1.155621        -0.970050     -1.699361     -0.220704
# ...                ...              ...           ...           ...
# 72529        -0.437193         0.886253      1.573702      0.141302
# 72530        -0.431953         0.717619      1.723958      0.188589
# 72531        -0.538545         0.809793      1.569945      0.195110
# 72532        -0.459524         0.756500      1.582542      0.323924
# 72535        -0.510497         0.915830      1.972349      0.272750
#
#        right_wristX  right_wristY  left_shoulderX  left_shoulderY  \
# 0         -1.165275     -0.221305       -1.318664        0.190818
# 1         -1.384241     -0.157161       -1.410776        0.164793
# 112       -1.363239     -0.189464       -1.362186        0.153217
# 154       -1.129820     -0.145221       -1.363168        0.093702
# 165       -1.237843     -0.265374       -1.355336        0.149263
# ...             ...           ...             ...             ...
# Here I put all Video Numbers in the datas into a sorted set to loop through in order to make packages of 20 Frames from every video sample. That way the network has still enough frames but more samples to learn from. Also the packages all have the same amount of frames. In the process I normalize all features for scale. Each person appears at different size when walking towards the camera. Therefore I move each persons features into a coordinate system, where their nose is the origin and scale all of them according to a reference size. That way all features are robust to scale changes during the video. The Scaling is analog to the one in the paper "Emotion recognition using Kinect motion-capture data of human gaits" by Shun Li et al.

# %%
df_b = df4.copy()
num_vid = list(sorted(set(df_b["VideoNr"].values)))

# %%
from scipy.spatial import distance

frames=[]
data_g = []
features=[]
pack = []

num_frame = 0

for video in tqdm(num_vid):
    
    gait=[]
    label=video[3:]
    folder=video[0]
    frames=[]
    features=[]
    pack_size = 19 #how many frames there should be in one sample

    for row in range(0,len(df_b.index)):
                
        if(df_b.loc[row,("VideoNr")] == video):
            
            if(num_frame<=pack_size): 
                num_frame+=1
                features = df_b.loc[row,(df_b.columns[4:])].tolist()
                pack.append(features)
                
            else:
                
                #once enough frames are in the package, they all need to be scaled for size
                h = 300 # uniform reference size
                
                #middlepoint of hip
                mp_hip = [ (df_b.loc[row,("right_hipX")] + df_b.loc[row,("left_hipX")])*0.5,
                           (df_b.loc[row,("right_hipY")] + df_b.loc[row,("left_hipY")])*0.5 ] 
                
                #moving coordinate system, so that nose is at (0,0)
                new_origin = [ abs(df_b.loc[row,("noseX")]), abs(df_b.loc[row,("noseY")]) ]
                
                #person size(hip and nose)
                pers_scale = [ distance.euclidean(new_origin[0], mp_hip[0]),
                               distance.euclidean(new_origin[1], mp_hip[1]) ] 
                
                #scale all joints in the pack
                for frame in pack:
                    for j in frame:
                        j = (j - new_origin[0]) * (pers_scale[0]/h)
                
                #put pack into dataframe
                data_g.append([label,folder,video, pack])
                
                #reset
                num_frame=0
                pack = []
# Out:
# HBox(children=(IntProgress(value=0, max=367), HTML(value='')))

# %%
df_3d = pd.DataFrame(data_g, columns = ["ID","Folder","Videoname", "Gait"])
df_3d
# Out:
#       ID Folder Videoname  \
# 0     01      1     1_001
# 1     01      1     1_001
# 2     01      1     1_001
# 3     01      1     1_001
# 4     01      1     1_001
# ...   ..    ...       ...
# 3453  62      6     6_062
# 3454  62      6     6_062
# 3455  62      6     6_062
# 3456  62      6     6_062
# 3457  62      6     6_062
#
#                                                                                                      Gait
# 0     [[6.145159768783847, -3.5423749813550796, -3.3708293723367886, 0.23128835707276635, -1.159242353...
# 1     [[1.9886155738568825, -4.921972112441757, -2.0944874182306568, 0.8068518798514708, -2.7840735532...
# 2     [[1.1275399489969578, -4.707025450859268, 0.1293137546816684, 0.7045429655107176, -4.02894030603...
# 3     [[0.9547622608992645, -4.496748724485409, 2.5327771286190743, -0.19808121615317503, -3.549206571...
# 4     [[3.0437848608634366, -3.8025692592891507, -1.193002683227392, 2.04956855385584, -0.821966242930...
# ...                                                                                                   ...
# 3453  [[-0.972252131557955, 0.18090995619391442, -0.05785556045112785, -0.23729410884444832, 0.1879322...
# 3454  [[0.7996680555940581, 5.8442549066167295, -0.45337113372660337, -0.43320086970858984, 0.99061554...
# 3455  [[0.48628386629819925, 5.601357875093558, -0.3494067879179643, -0.6242942336219933, 0.9360567412...
# 3456  [[0.3899169847592733, 6.169223341772046, -0.46872826542959334, -0.6402638731651413, 0.9007125056...
# 3457  [[0.5347514262716961, 4.478374379676929, -0.12516478389361116, -0.08860242148949003, 1.113618764...
#
# [3458 rows x 4 columns]

# %% [markdown]
# The data now consists from 1190 Samples with 20 Frames each, which contain 23 features

# %%
print( str(  len(  df_3d["Gait"]          )) + " Samples"    )
print( str(  len(  df_3d["Gait"][0]       )) + " Frames per Sample"    )
print( str(  len(  df_3d["Gait"][0][0]    )) + " Joints per Frame"    )
# Out:
# 3458 Samples
# 20 Frames per Sample
# 28 Joints per Frame

# %% [markdown]
# # Removing Videos of Subjects with black Tshirt in front of black background

# %% [markdown]
# I noticed that the 2d pose estimation often fails with particular subjects that wear uniformly black colored tshirts and are filmed in front of the unfortunately black background. Here I dropped some samples that were particularly unlikely to get correct joint positions, even for human eyes.

# %%
df_final = df_3d.copy()
To_remove = ["1_030",  "1_033",  "1_034",  "1_035",  "1_038",
             "2_008",  "2_030",  "2_008",  "2_034",  "2_042",
             "3_001",  "3_008",  "3_017",  "3_025",  "3_031", 
             "4_008",  "4_030",  "4_035",  "4_044",  "3_052",
             "1_003",  "2_003",  "3_003",  "4_003",  "5_003",  #003,012,17,25,26,22,53,45,52,25,46,47,50,56
             "1_012",  "2_012",  "3_012",  "4_012",  "5_012",  
             "1_017",  "2_017",  "3_017",  "4_017",  "5_017",  
             "1_025",  "2_025",  "3_025",  "4_025",  "5_025", 
             "1_026",  "2_026",  "3_026",  "4_026",  "5_026", 
             "1_022",  "2_022",  "3_022",  "4_022",  "5_022", 
             "1_053",  "2_053",  "3_053",  "4_053",  "5_053", 
             "1_045",  "2_045",  "3_045",  "4_045",  "5_045",  
             "1_052",  "2_052",  "3_052",  "4_052",  "5_052",
             "1_025",  "2_025",  "3_025",  "4_025",  "5_025", 
             "1_046",  "2_046",  "3_046",  "4_046",  "5_046",
             "1_047",  "2_047",  "3_047",  "4_047",  "5_047",
             "1_050",  "2_050",  "3_050",  "4_050",  "5_050",
             "1_056",  "2_056",  "3_056",  "4_056",  "5_056",
             "2_044",  "3_034",  "3_044",  "3_051"]

# %%
df_final.index = [x for x in range(0, 3458)]

# %%
for video in To_remove:
    df_final = df_final[df_final.Videoname != video]
    
df_final
# Out:
#       ID Folder Videoname  \
# 0     01      1     1_001
# 1     01      1     1_001
# 2     01      1     1_001
# 3     01      1     1_001
# 4     01      1     1_001
# ...   ..    ...       ...
# 3453  62      6     6_062
# 3454  62      6     6_062
# 3455  62      6     6_062
# 3456  62      6     6_062
# 3457  62      6     6_062
#
#                                                                                                      Gait
# 0     [[6.145159768783847, -3.5423749813550796, -3.3708293723367886, 0.23128835707276635, -1.159242353...
# 1     [[1.9886155738568825, -4.921972112441757, -2.0944874182306568, 0.8068518798514708, -2.7840735532...
# 2     [[1.1275399489969578, -4.707025450859268, 0.1293137546816684, 0.7045429655107176, -4.02894030603...
# 3     [[0.9547622608992645, -4.496748724485409, 2.5327771286190743, -0.19808121615317503, -3.549206571...
# 4     [[3.0437848608634366, -3.8025692592891507, -1.193002683227392, 2.04956855385584, -0.821966242930...
# ...                                                                                                   ...
# 3453  [[-0.972252131557955, 0.18090995619391442, -0.05785556045112785, -0.23729410884444832, 0.1879322...
# 3454  [[0.7996680555940581, 5.8442549066167295, -0.45337113372660337, -0.43320086970858984, 0.99061554...
# 3455  [[0.48628386629819925, 5.601357875093558, -0.3494067879179643, -0.6242942336219933, 0.9360567412...
# 3456  [[0.3899169847592733, 6.169223341772046, -0.46872826542959334, -0.6402638731651413, 0.9007125056...
# 3457  [[0.5347514262716961, 4.478374379676929, -0.12516478389361116, -0.08860242148949003, 1.113618764...
#
# [2698 rows x 4 columns]

# %% [markdown]
# # 4) Creating the Neural Network

# %% [markdown]
# Here I use the Gait-Pattern as Input X and the ID-Column as the Labels Y,
# then I compare the shapes of the two vectors, in case something is missing. I split the Training Data in a way so that the 6th folder is used for validation and Training is done with all other folders. Then I encode the y-Vectors which were just strings with number (p.e "023") before.

# %%
#the pattern array needs to be a 3dimensional input for the LSTM
# Data needs to be in the shape (sample, frame_number, coordinates)

df_train = df_final.loc[df_final['Folder'] != '6']
df_test = df_final.loc[df_final['Folder'] == '6']

X_train = np.array([x for x in df_train["Gait"]])
X_test = np.array([x for x in df_test["Gait"]])

y_train = np.array(df_train["ID"])
y_test = np.array(df_test["ID"])

y_train = to_categorical(y_train,63)
y_test = to_categorical(y_test,63)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
inp = X_train.shape[1:]
# Out:
# (2030, 20, 28)
# (2030, 63)
# (668, 20, 28)
# (668, 63)

# %% [markdown]
# If you are using Cuda support for nvidia graphic cards, you can actually use CuDNNLSTM this way, which gives a calculation boost of about 15 times the speed of the normal LSTM because it not only uses parallel calculations of the gpu but is also optimized for it, instead of cpu computation.

# %%
from keras.layers import Dense, BatchNormalization, LSTM, Conv2D, Conv3D, Flatten, CuDNNLSTM
from keras.models import Sequential   
from keras import regularizers
import tensorflow as tf


# Neural network
model = Sequential()

#Input Layer
model.add(CuDNNLSTM(512, input_shape=inp,
              kernel_regularizer=regularizers.l2(0.01),
              recurrent_regularizer=None,
              bias_regularizer=regularizers.l2(0.01),
              return_sequences=True))


model.add(BatchNormalization(name='BatchNormalization1'))

#Layer 2

model.add(CuDNNLSTM(256, kernel_regularizer=regularizers.l2(0.01),
              recurrent_regularizer=None,
              bias_regularizer=regularizers.l2(0.01),
              return_sequences=True))

model.add(BatchNormalization(name='BatchNormalization2'))

#Layer 3

model.add(Dense(256, activation='tanh', name='Layer3'))
model.add(BatchNormalization(name='BatchNormalization3'))

#Layer 4
model.add(Dense(128, activation='tanh', name='Layer4'))
model.add(BatchNormalization(name='BatchNormalization4'))

#Dense Layer
model.add(Flatten())
model.add(Dense(63, activation='softmax',name='Final_Layer'))

# %%
from keras.optimizers import SGD
opt = SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)

# %%
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_5 (CuDNNLSTM)     (None, 20, 512)           1110016
# _________________________________________________________________
# BatchNormalization1 (BatchNo (None, 20, 512)           2048
# _________________________________________________________________
# cu_dnnlstm_6 (CuDNNLSTM)     (None, 20, 256)           788480
# _________________________________________________________________
# BatchNormalization2 (BatchNo (None, 20, 256)           1024
# _________________________________________________________________
# Layer3 (Dense)               (None, 20, 256)           65792
# _________________________________________________________________
# BatchNormalization3 (BatchNo (None, 20, 256)           1024
# _________________________________________________________________
# Layer4 (Dense)               (None, 20, 128)           32896
# _________________________________________________________________
# BatchNormalization4 (BatchNo (None, 20, 128)           512
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2560)              0
# _________________________________________________________________
# Final_Layer (Dense)          (None, 63)                161343
# =================================================================
# Total params: 2,163,135
# Trainable params: 2,160,831
# Non-trainable params: 2,304
# _________________________________________________________________

# %% [markdown]
# # 5) Training the Network

# %% [markdown]
# The classes are relatively unbalanced, because some videos provide more frames than others. Instead of removing the frames to balance it out, I weighted the class labels depending on occurrence.

# %%
#df_train.ID.value_counts()

# %%
from sklearn.utils import compute_class_weight

y_w = [np.argmax(x) for x in y_train]
classWeight = compute_class_weight('balanced', np.unique(y_w), y_w) 
classWeight = dict(enumerate(classWeight))

    
#This below is to solve a Keras bug where it doesn't accept an equal number of labels
classWeight[62] = 1.0061770761839397
print(classWeight)
# Out:
# {0: 0.8057347670250896, 1: 0.7399605003291639, 2: 6.043010752688172, 3: 0.7109424414927261, 4: 0.8240469208211144, 5: 0.7553763440860215, 6: 0.7399605003291639, 7: 1.8129032258064517, 8: 0.9296939619520265, 9: 0.7714481811942348, 10: 0.8057347670250896, 11: 5.179723502304148, 12: 0.8843430369787569, 13: 0.8240469208211144, 14: 0.8632872503840245, 15: 0.979947689625109, 16: 2.7890818858560795, 17: 0.8432108027006752, 18: 0.9541595925297114, 19: 0.979947689625109, 20: 1.0359447004608295, 21: 3.021505376344086, 22: 0.8432108027006752, 23: 0.8843430369787569, 24: 4.532258064516129, 25: 5.179723502304148, 26: 0.9064516129032258, 27: 0.8057347670250896, 28: 0.9296939619520265, 29: 1.3945409429280398, 30: 0.8843430369787569, 31: 0.7399605003291639, 32: 0.8432108027006752, 33: 1.294930875576037, 34: 1.0664136622390892, 35: 0.5578163771712159, 36: 0.7399605003291639, 37: 0.9541595925297114, 38: 0.6841144248326233, 39: 0.6592375366568914, 40: 0.6841144248326233, 41: 0.8057347670250896, 42: 0.6474654377880185, 43: 1.2086021505376343, 44: 4.028673835125448, 45: 3.2961876832844577, 46: 4.028673835125448, 47: 0.6145434663750683, 48: 0.8432108027006752, 49: 4.028673835125448, 50: 0.9541595925297114, 51: 5.179723502304148, 52: 5.179723502304148, 53: 0.8632872503840245, 54: 0.7714481811942348, 55: 3.6258064516129034, 56: 0.788218793828892, 57: 0.8240469208211144, 58: 0.7714481811942348, 59: 0.7714481811942348, 60: 0.7714481811942348, 61: 0.788218793828892, 62: 1.0061770761839397}

# %% [markdown]
# I tried many different hyperparameters but found that this batch size and epoch count works best for the model

# %%
history = model.fit(X_train, 
                    y_train, 
                    validation_data = (X_test,y_test),
                    epochs=600,
                    batch_size=16,
                    verbose = 2,
                    class_weight=classWeight)
# Out:
# Train on 2248 samples, validate on 450 samples
# Epoch 1/600
#  - 1s - loss: 0.8446 - acc: 0.9742 - val_loss: 2.4300 - val_acc: 0.6422
# Epoch 590/600
#  - 1s - loss: 0.7874 - acc: 0.9933 - val_loss: 2.4034 - val_acc: 0.6489
# Epoch 591/600
#  - 1s - loss: 0.7817 - acc: 0.9942 - val_loss: 2.3563 - val_acc: 0.6444
# Epoch 592/600
#  - 1s - loss: 0.7728 - acc: 0.9938 - val_loss: 2.4605 - val_acc: 0.6422
# Epoch 593/600
#  - 1s - loss: 0.7869 - acc: 0.9875 - val_loss: 2.5278 - val_acc: 0.6311
# Epoch 594/600
#  - 1s - loss: 1.1125 - acc: 0.9204 - val_loss: 2.6370 - val_acc: 0.5956
# Epoch 595/600
#  - 1s - loss: 0.8118 - acc: 0.9773 - val_loss: 2.6085 - val_acc: 0.5933
# Epoch 596/600
#  - 1s - loss: 0.7855 - acc: 0.9849 - val_loss: 2.5074 - val_acc: 0.6133
# Epoch 597/600
#  - 1s - loss: 0.8017 - acc: 0.9822 - val_loss: 2.4729 - val_acc: 0.5978
# Epoch 598/600
#  - 1s - loss: 0.7652 - acc: 0.9898 - val_loss: 2.5382 - val_acc: 0.6089
# Epoch 599/600
#  - 1s - loss: 0.7702 - acc: 0.9853 - val_loss: 2.4471 - val_acc: 0.6267
# Epoch 600/600
#  - 1s - loss: 0.7648 - acc: 0.9893 - val_loss: 2.3617 - val_acc: 0.6378

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 

plt.xlabel('Epoch') 
plt.legend(['Train', 'Validation'], loc='upper left') 
plt.show()

# %% [markdown]
# After taking a look at the loss, I always calculate the overall accuracy of the models predictions

# %%
y_pred = model.predict(X_test)

#Converting predictions to label
pred = list()
for i in range(len(y_pred)):
    pred.append(np.argmax(y_pred[i]))

#Converting one hot encoded test label to label
test = list()
for i in range(len(y_test)):
    test.append(np.argmax(y_test[i]))

# %%
from sklearn.metrics import accuracy_score
a = accuracy_score(pred,test)
print('Accuracy on the Validation Data is:', a*100)
# Out:
# Accuracy on the Validation Data is: 63.77777777777778

# %% [markdown]
# Below is the precision and accuracy for each class, interestingly some are way harder to predict than others because some subjects for example where black tshirts in front of black backgrounds and are therefore missing joints.

# %%
from sklearn.metrics import classification_report

y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
y_pred = model.predict_classes(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.50      0.67         8
#            2       0.60      1.00      0.75         3
#            3       1.00      1.00      1.00         2
#            4       0.57      0.57      0.57         7
#            5       0.88      0.58      0.70        12
#            6       0.64      0.70      0.67        10
#            7       0.62      0.71      0.67         7
#            8       0.57      0.80      0.67         5
#            9       0.62      0.67      0.64        12
#           10       0.64      0.88      0.74         8
#           11       0.50      1.00      0.67         5
#           12       0.00      0.00      0.00         2
#           13       0.75      0.64      0.69        14
#           14       0.67      0.55      0.60        11
#           15       0.64      0.64      0.64        11
#           16       0.75      0.67      0.71         9
#           17       0.00      0.00      0.00         2
#           18       0.43      0.43      0.43         7
#           19       0.75      0.90      0.82        10
#           20       0.44      0.44      0.44         9
#           21       0.62      0.91      0.74        11
#           22       1.00      1.00      1.00         1
#           23       0.50      0.40      0.44         5
#           24       0.62      0.83      0.71         6
#           25       0.00      0.00      0.00         1
#           26       0.00      0.00      0.00         1
#           27       0.33      0.33      0.33         6
#           28       0.44      0.70      0.54        10
#           29       0.45      0.50      0.48        10
#           30       0.40      0.40      0.40         5
#           31       0.45      0.71      0.56         7
#           32       0.83      0.45      0.59        11
#           33       0.86      0.86      0.86         7
#           34       0.75      0.75      0.75         4
#           35       1.00      0.50      0.67        10
#           36       0.67      0.55      0.60        11
#           37       0.78      0.78      0.78         9
#           38       0.89      0.73      0.80        11
#           39       0.67      0.22      0.33         9
#           40       0.80      0.57      0.67        14
#           41       0.80      0.50      0.62         8
#           42       0.73      0.67      0.70        12
#           43       0.67      0.60      0.63        10
#           44       1.00      0.50      0.67         4
#           45       0.67      0.50      0.57         4
#           46       0.17      1.00      0.29         1
#           47       0.33      0.50      0.40         2
#           48       0.91      1.00      0.95        10
#           49       0.77      0.77      0.77        13
#           50       0.00      0.00      0.00         2
#           51       0.38      0.43      0.40         7
#           52       0.75      1.00      0.86         3
#           53       0.33      0.33      0.33         3
#           54       0.70      0.64      0.67        11
#           55       0.50      0.67      0.57         6
#           56       0.50      0.50      0.50         2
#           57       0.62      0.50      0.56        10
#           58       0.56      0.83      0.67         6
#           59       1.00      1.00      1.00         7
#           60       0.64      0.70      0.67        10
#           61       0.43      0.50      0.46         6
#           62       0.57      0.80      0.67        10
#
#    micro avg       0.64      0.64      0.64       450
#    macro avg       0.60      0.61      0.58       450
# weighted avg       0.66      0.64      0.63       450

# %% [markdown]
# # Indoor/Outdoor/Flashlight Classification

# %% [markdown]
# Now a neural network is trained to classify, whether each video is outdoor, indoor or filmed with a flashlight inside.
# There for first, I define a dictionary to automatically label videos correctly based on their name.

# %%
classes = dict({'1':"Indoor light",
                '2':"Indoor light",
                '3':"Indoor flash",
                '4':"Indoor flash",
                '5':"Outdoor",
                '6':"Outdoor"
               })
classes['1']
# Out:
# 'Indoor light'

# %% [markdown]
# Then I grab two frames from every video and put them in a dataframe, where they all have a label and a calculated histogram of their grayscale version. The Videos are already easily distinguishable by contrast differences, so no colors are needed. I just flatten them and then save their histogram in the array

# %%
path_frames = './lowres_rot/'

frames = []
m=0

for file in tqdm(sorted(os.listdir(path_frames))):
   

    if('frame029' in file or 'frame010' in file): #takign frame number 29 from every video
        m+=1
        
        #get label
        label = classes[file[0]]
        
        #get one frame
        img = plt.imread(path_frames+file)
        img_n = np.array(img)
        
        #get histogram
        vals = img_n.mean(axis=2).flatten()  # calculate mean value from RGB channels and flatten to 1D array        
        h = np.histogram(vals, 255)  # plot histogram with 255 bins
        hist = np.array(h[0], dtype=float)
        
        frames.append([label,img_n,hist])
        cv2.destroyAllWindows()
        

print(str(m) + " frames found")
# Out:
# HBox(children=(IntProgress(value=0, max=72622), HTML(value='')))
# 4485 frames found

# %% [markdown]
# #### Below is the resulting dataframe:
# Each histogram consists of an 1dimensional array with 255 values, one for each brightness level of rgb. The Image Array is just there to load the images if needed. They are in numpy array shape meaning 192 x 108 Pixels with 3 rgb color channels each.

# %%
df_c = pd.DataFrame(frames, columns = ["Label", "Image-Array","Histogram"])
df_c
# Out:
#              Label  \
# 0     Indoor light
# 1     Indoor light
# 2     Indoor light
# 3     Indoor light
# 4     Indoor light
# ...            ...
# 4480       Outdoor
# 4481       Outdoor
# 4484  [3.0, 3.0, 10.0, 15.0, 22.0, 27.0, 28.0, 33.0, 47.0, 55.0, 57.0, 63.0, 69.0, 76.0, 83.0, 82.0, 8...
#
# [4485 rows x 3 columns]

# %% [markdown]
# Now I just use the Histogram Array as an Input X and the Labels as the Target Y

# %%
X = np.array([ x for x in df_c["Histogram"]])

y = np.array(df_c["Label"])
print(X.shape)
print(y.shape)
# Out:
# (4485, 255)
# (4485,)

# %% [markdown]
# Then I normalize the histogram data and encode the String Labels with a Labelencoder plus to Categorical,
# in order to be able to train with Arrays containing only 1 and 0. Additionally I write a little decoding dictionary for later.

# %%
from sklearn.preprocessing import StandardScaler

#Normalizing the data
sc = StandardScaler()
X = sc.fit_transform(X)

#Encoding the Labels
label_encoder = LabelEncoder()
vec = label_encoder.fit_transform(y)
y_enc = to_categorical(vec)

decode = dict({0:'indoor flash',
               1:'indoor Light',
               2:'outdoor'})

# %% [markdown]
# As always the data gets split 9:1 in training and validation data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_enc, test_size=0.1, random_state=42)
print(X_train.shape)
print(y_train.shape)
# Out:
# (4036, 255)
# (4036, 3)

# %% [markdown]
# Here I use a really tiny network to not immediately overfit, because the amount of data is so small.

# %%
# Neural network
model = Sequential()

#Input Layer
model.add(Dense(4, input_shape=(255,), activation='relu',name='Input_Layer'))
model.add(BatchNormalization(name='BatchNormalization1'))

#Final Layer
model.add(Dense(3, activation='softmax',name='Final_Layer'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (Dense)          (None, 4)                 1024
# _________________________________________________________________
# BatchNormalization1 (BatchNo (None, 4)                 16
# _________________________________________________________________
# Final_Layer (Dense)          (None, 3)                 15
# =================================================================
# Total params: 1,055
# Trainable params: 1,047
# Non-trainable params: 8
# _________________________________________________________________

# %% [markdown]
# Already after 6 epochs, the training is done:

# %%
history = model.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=6, batch_size=32)
# Out:
# Train on 4036 samples, validate on 449 samples
# Epoch 1/6
# 4036/4036 [==============================] - ETA: 1:37 - loss: 1.0721 - acc: 0.437 - ETA: 5s - loss: 0.9854 - acc: 0.5723  - ETA: 2s - loss: 0.8329 - acc: 0.652 - ETA: 1s - loss: 0.7529 - acc: 0.688 - ETA: 0s - loss: 0.6796 - acc: 0.725 - ETA: 0s - loss: 0.6392 - acc: 0.749 - ETA: 0s - loss: 0.6035 - acc: 0.768 - ETA: 0s - loss: 0.5759 - acc: 0.784 - 1s 327us/step - loss: 0.5565 - acc: 0.7941 - val_loss: 0.3626 - val_acc: 0.8931
# Epoch 2/6
# 4036/4036 [==============================] - ETA: 0s - loss: 0.3480 - acc: 0.906 - ETA: 0s - loss: 0.3576 - acc: 0.902 - ETA: 0s - loss: 0.3433 - acc: 0.912 - ETA: 0s - loss: 0.3268 - acc: 0.922 - ETA: 0s - loss: 0.3120 - acc: 0.930 - ETA: 0s - loss: 0.3023 - acc: 0.935 - ETA: 0s - loss: 0.2927 - acc: 0.937 - ETA: 0s - loss: 0.2827 - acc: 0.941 - 0s 104us/step - loss: 0.2771 - acc: 0.9440 - val_loss: 0.2022 - val_acc: 0.9555
# Epoch 3/6
